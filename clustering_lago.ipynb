# %% [markdown]
# <a href="https://colab.research.google.com/github/mleyvaz/vision-computadoras/blob/main/clustering_lago.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Área Lago

# %% [markdown]
# Segmentacion

# %%
#Librerias 
import numpy as np
import pandas as pd
import cv2  
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image 
import matplotlib.pylab as plt

# %% [markdown]
#  plot an image in 3D space using python matplotlib library.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
img =  io.imread('https://blogtoppy777.files.wordpress.com/2008/04/3victoriaa.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
r, g, b = cv2.split(img)
r = r.flatten()
g = g.flatten()
b = b.flatten()#plotting 
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(r, g, b)
plt.show()
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=425x438 at 0x7F3C1861BCD0>

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
vectorized = img.reshape((-1,3))
vectorized = np.float32(vectorized)
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
K = 2
attempts=10
ret,label,center=cv2.kmeans(vectorized,K,None,criteria,attempts,cv2.KMEANS_PP_CENTERS)
center = np.uint8(center)
res = center[label.flatten()]
result_image = res.reshape((img.shape))

cv2_imshow(result_image)
# Out:
# <PIL.Image.Image image mode=RGB size=425x438 at 0x7F3C0A86CD50>
