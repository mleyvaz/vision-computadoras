# %% [markdown]
# <a href="https://colab.research.google.com/github/mleyvaz/vision-computadoras/blob/main/Operaciones_sobre_grupos_de_puntos-Filtro%20media.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Librerias 
import numpy as np
import pandas as pd
import cv2  
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image 
import matplotlib.pylab as plt

# %%
url2="https://upload.wikimedia.org/wikipedia/commons/thumb/f/f4/Noise_salt_and_pepper.png/220px-Noise_salt_and_pepper.png"
image1 = io.imread(url2) 
cv2_imshow(image1) 
median=cv2.medianBlur (image1, 21)
cv2_imshow(median)
# Out:
# <PIL.Image.Image image mode=RGB size=220x294 at 0x7FA9C0E8EE50>
# <PIL.Image.Image image mode=RGB size=220x294 at 0x7FA9C0E8ED50>

# %% [markdown]
# Aplique el Filtro Correspondiente a la Siguiente Imagen
# ![image.png](data:image/png;base64,...)

# %%
url="http://4.bp.blogspot.com/-ySiRK8rBDtU/URxXzATeTFI/AAAAAAAACfw/_flXm9G2G1Y/s320/salt-snoopy.png"
image1=io.imread(url)
cv2_imshow(image1) 
median=cv2.medianBlur (image1, 21)
cv2_imshow(median)
# Out:
# <PIL.Image.Image image mode=RGB size=320x236 at 0x7FA9CB3856D0>
# <PIL.Image.Image image mode=RGB size=320x236 at 0x7FA9C0E1B550>

# %% [markdown]
# Ejercicio : Mejore la calidad de las imágenes una vez aplicado el filtro media y apliquela a la imagen
# ![image.png](data:image/png;base64,...)

# %%
# imagen https://static-01.hindawi.com/articles/cmmm/volume-2014/690349/figures/690349.fig.005d.jpg
