# %% [markdown]
# <a href="https://colab.research.google.com/github/mleyvaz/vision-computadoras/blob/main/Normalizacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Librerias 
import numpy as np
import pandas as pd
import cv2  
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image 
import matplotlib.pylab as plt

# %%
url1="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS9WE1IGZlR-J8_ngYfWomTeRdX17jLqmLz4Q&usqp=CAU"
img = io.imread(url1) 
cv2_imshow(img) 
norm_img = np.zeros((300, 300))
norm_img = cv2.normalize(img, norm_img, 0, 255, cv2.NORM_MINMAX)
cv2_imshow(norm_img)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F7E808C5F90>
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F7E808C50D0>

# %% [markdown]
# Normalizar imagen
# https://upload.wikimedia.org/wikipedia/commons/thumb/b/b3/Colonic_Herniation_08787.jpg/290px-Colonic_Herniation_08787.jpg
# Conviertalo a RGB y muestre los resultados compare los  histograma de color gris
# ```
# image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
# # hist = cv2.calcHist([img], [0], None, [256], [0, 256])
# plt.plot(hist, color='gray' )
#
# plt.xlabel('intensidad de iluminacion')
# plt.ylabel('cantidad de pixeles')
# plt.show()
# ```

# %%
url1="https://upload.wikimedia.org/wikipedia/commons/thumb/b/b3/Colonic_Herniation_08787.jpg/290px-Colonic_Herniation_08787.jpg"
image = io.imread(url1) 
image_2 = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
hist = cv2.calcHist([image_2], [0], None, [256], [0, 256])
plt.plot(hist, color='gray' )
 
plt.xlabel('intensidad de iluminacion')
plt.ylabel('cantidad de pixeles')
plt.show()
