# %% [markdown]
# <a href="https://colab.research.google.com/github/mleyvaz/vision-computadoras/blob/main/Filtros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Librerias 
import numpy as np
import pandas as pd
import cv2  
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image 
import matplotlib.pylab as plt

# %%
url2="https://static-01.hindawi.com/articles/cmmm/volume-2014/690349/figures/690349.fig.006e.jpg"
image1 = io.imread(url2) 
cv2_imshow(image1) 
median=cv2.medianBlur (image1, 7)
cv2_imshow(median)
# Out:
# <PIL.Image.Image image mode=RGB size=446x443 at 0x7F87F68F9470>
# <PIL.Image.Image image mode=RGB size=446x443 at 0x7F87F68F9278>

# %%
img=cv2.cvtColor(median,cv2.COLOR_BGR2RGB)
vectorized = img.reshape((-1,3))
vectorized = np.float32(vectorized)
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
K = 2
attempts=10
ret,label,center=cv2.kmeans(vectorized,K,None,criteria,attempts,cv2.KMEANS_PP_CENTERS)
center = np.uint8(center)
res = center[label.flatten()]
result_image = res.reshape((img.shape))
cv2_imshow(result_image)
# Out:
# <PIL.Image.Image image mode=RGB size=446x443 at 0x7F87F60220B8>

# %%
url2="https://th.bing.com/th/id/Rb630c28624d6086327bcdd871aef490f?rik=eMv0QDAsxO0VrA&riu=http%3a%2f%2fvision.cse.psu.edu%2fresearch%2ftumorDetect%2fimages%2f2011koshy1.png&ehk=MdN0lx7diMYdtHOS%2bcUdjokKVWZuFp8r50EaRarx1dE%3d&risl=&pid=ImgRaw"
image1 = io.imread(url2) 
img=cv2.cvtColor(image1,cv2.COLOR_BGR2RGB)
vectorized = img.reshape((-1,3))
vectorized = np.float32(vectorized)
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
K = 5
attempts=10
ret,label,center=cv2.kmeans(vectorized,K,None,criteria,attempts,cv2.KMEANS_PP_CENTERS)
center = np.uint8(center)
res = center[label.flatten()]
result_image = res.reshape((img.shape))
cv2_imshow(result_image)
# Out:
# <PIL.Image.Image image mode=RGB size=379x419 at 0x7F87F68F9E48>
