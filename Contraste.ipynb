# %% [markdown]
# <a href="https://colab.research.google.com/github/mleyvaz/vision-computadoras/blob/main/Contraste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Librerias 
import numpy as np
import pandas as pd
import cv2 as cv 
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image 
import matplotlib.pylab as plt

# %%
url="https://upload.wikimedia.org/wikipedia/commons/thumb/6/67/Inside_the_Batad_rice_terraces.jpg/220px-Inside_the_Batad_rice_terraces.jpg"
image = io.imread(url) 
# Check the image matrix data type (could know the bit depth of the image)
print(image.dtype)
# Check the height of image 
print(image.shape[0])
# Check the width of image 
print(image.shape[1])
# Check the number of channels of the image
print(image.shape[2])
# Out:
# uint8
# 151
# 220
# 3

# %%
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv.calcHist([image],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=220x151 at 0x7FFA6FBF3650>

# %%
contrast_img = cv.addWeighted(image, 2.5, np.zeros(image.shape, image.dtype), 0, 0)

#cv2_imshow( image)

#cv2_imshow( contrast_img)
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
contimage_2=cv.cvtColor(contrast_img, cv.COLOR_BGR2RGB)
cv2_imshow(image_2)
cv2_imshow(contimage_2)
# Out:
# <PIL.Image.Image image mode=RGB size=220x151 at 0x7FFA6FB361D0>
# <PIL.Image.Image image mode=RGB size=220x151 at 0x7FFA6FB36650>

# %%
color = ('r','g','b')
for i,col in enumerate(color):
    histr = cv.calcHist([image_2],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
cv2_imshow(image_2)
# Out:
# <PIL.Image.Image image mode=RGB size=220x151 at 0x7FFA6FB66F10>

# %%
# Imagen contraste 
color = ('r','g','b')
for i,col in enumerate(color):
    histr = cv.calcHist([contimage_2],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
cv2_imshow(contimage_2)
# Out:
# <PIL.Image.Image image mode=RGB size=220x151 at 0x7FFA6FADF790>

# %%
# Ejercicio : Carge una imagen de la web , conviertala a RGB y encuentre el histograma de esos 3 colores
